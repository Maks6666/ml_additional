# %%
from sklearn.datasets import make_classification
from collections import Counter
from sklearn.model_selection import train_test_split

# %%
x, y = make_classification(
    n_samples=5000,
    n_features=20,
    n_informative=5,
    n_redundant=2,
    weights=[0.95, 0.05],
    random_state=42
)

# %%
x[0], y[0]
# Out:
# (array([ 0.80349394,  0.55143428,  0.00325882,  2.0703873 , -0.28461194,
#         -1.75060523, -0.72606365,  0.83827991, -0.7058053 , -1.64175399,
#          0.64725807, -0.66519038, -2.43131237,  1.52310067,  0.55687179,
#          0.24721416, -0.18538403, -0.58139877,  0.0724405 , -0.96899425]),
#  np.int64(0))

# %%
print(Counter(y))
# Out:
# Counter({np.int64(0): 4730, np.int64(1): 270})

# %%
# !pip install imblearn
# Out:
# Requirement already satisfied: imblearn in /opt/anaconda3/envs/mlflow3/lib/python3.10/site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in /opt/anaconda3/envs/mlflow3/lib/python3.10/site-packages (from imblearn) (0.14.1)
# Requirement already satisfied: numpy<3,>=1.25.2 in /opt/anaconda3/envs/mlflow3/lib/python3.10/site-packages (from imbalanced-learn->imblearn) (2.0.1)
# Requirement already satisfied: scipy<2,>=1.11.4 in /opt/anaconda3/envs/mlflow3/lib/python3.10/site-packages (from imbalanced-learn->imblearn) (1.15.3)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in /opt/anaconda3/envs/mlflow3/lib/python3.10/site-packages (from imbalanced-learn->imblearn) (1.7.1)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in /opt/anaconda3/envs/mlflow3/lib/python3.10/site-packages (from imbalanced-learn->imblearn) (0.1.5)
# Requirement already satisfied: joblib<2,>=1.2.0 in /opt/anaconda3/envs/mlflow3/lib/python3.10/site-packages (from imbalanced-learn->imblearn) (1.5.1)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /opt/anaconda3/envs/mlflow3/lib/python3.10/site-packages (from imbalanced-learn->imblearn) (3.6.0)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y)

# %%
# example of oversampling - creating of syntetic examples

from imblearn.over_sampling import SMOTE
sm = SMOTE()
x_res, y_res = sm.fit_resample(x_train, y_train)

# %%
Counter(y_res)
# Out:
# Counter({np.int64(0): 3550, np.int64(1): 3550})

# %%
# example of undersampling cutting off random samples

from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler()
x_res, y_res = rus.fit_resample(x, y)

# %%
Counter(y_res)
# Out:
# Counter({np.int64(0): 270, np.int64(1): 270})
